# %% [markdown]
# # Lab 4: Deep Learning for Satellite Data
# This notebook uses a pre-made training dataset to develop a simple deep learning classifier for finding solar pannels in Sentinel 2 imagery. The learning objectives for this lab are to:
#
# 1. Load and use a pre-labeled training dataset (e.g. polygons or patches with land cover classes).
# 2. Prepare that data for use in a deep learning model.
# 3. Train a deep learning model in TensorFlow/Keras using these labels.
#
# At the end of the lab you will be asked to reflect on model performance, generalization, and sources of error.

# %%
# Set up, couple of new libraries here so expect install times to take longer than you have been used to
# !pip install -q tensorflow rasterio geemap matplotlib scikit-learn tqdm --quiet

import os
import zipfile
from pathlib import Path
import numpy as np
import re
import rasterio
import cv2
import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from tqdm import tqdm
from sklearn.model_selection import train_test_split
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 37.9 MB/s eta 0:00:00

# %%
# Set our random seeds for reproducibility
SEED = 42 #<- the meaning of life, this is why you always see people setting seeds to 42 by the way...
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# Your training data has been downloaded from:
#
# *   [Solafune](https://solafune.com/competitions/5dfc315c-1b24-4573-804f-7de8d707cd90?id=&menu=data&topicId=54728653-0e25-4975-baad-6fe2f5185844)
#
# Find the data on Canvas or download directly from their website the 'train.zip'. The competition that this dataset was created for is now over, but that is good for us as it means you can look at the winning solutions for inspiration!
#
# If you want to download the data yourself you will need to sign up for an account and then 'enter' the competition. You can do this all without charge but it does require an email address sign up.
#
# We are just going to use the 'train.zip' data and split that into our train and test, in order to reduce the burden on our notebooks. Remember that ultimately we would want to validate it, and you will see that the linked data source actually has a completely seperate store of images for that purpose.
#
# Take that .zip file and get it into your g-drive/local space as per usual practice. Leave it zipped.

# %%
# Assume train.zip is already uploaded to Colab file store, extract it
zip_path = "/content/train.zip"
extract_dir = Path("/content/train_data")
extract_dir.mkdir(parents=True, exist_ok=True)


with zipfile.ZipFile(zip_path, 'r') as z:
  z.extractall(extract_dir)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# With our data extracted, we now need to build lists of each sample patch and the labelled mask of it, connecting the two. I have written this relatively robustly (e.g. you can set it to handle different file extensions and it checks that it is finding the correct files), so that hopefully you can use it more widely than just in this lab.

# %%
# Set the file extenion we are using
f_ex = "*.tif"

# Locate directories
s2_dir = next((p for p in extract_dir.rglob('*') if p.is_dir() and 's2_image' in p.name.lower()), None)
mask_dir = next((p for p in extract_dir.rglob('*') if p.is_dir() and 'mask' in p.name.lower()), None)

assert s2_dir and mask_dir, "Could not locate s2_image/ and mask/ directories."
print("Found Sentinel-2 image dir:", s2_dir)
print("Found mask dir:", mask_dir)

# Match files to each other from each sub-directory by trailing numeric ID
s2_files = {re.search(r'_(\d+)\.tif$', f.name).group(1): f for f in Path(s2_dir).glob(f_ex)}
mask_files = {re.search(r'_(\d+)\.tif$', f.name).group(1): f for f in Path(mask_dir).glob(f_ex)}

# Build pairs of images and masks
common_ids = sorted(set(s2_files.keys()) & set(mask_files.keys()))
assert len(common_ids) > 0, "No paired s2_image/mask files found with matching IDs."

pairs = []
for i in common_ids:
    s2_path, mask_path = s2_files[i], mask_files[i]
    with rasterio.open(s2_path) as s2, rasterio.open(mask_path) as m:
        assert (s2.height, s2.width) == (m.height, m.width), \
            f"Shape mismatch: {s2_path.name} vs {mask_path.name}"
    pairs.append((s2_path, mask_path))

print(f"Found {len(pairs)} valid paired samples.")
print("Example pair:", pairs[0])
# Out:
# Found Sentinel-2 image dir: /content/train_data/s2_image
# Found mask dir: /content/train_data/mask
# /usr/local/lib/python3.13/dist-packages/rasterio/__init__.py:367: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, thread_safe=thread_safe, **kwargs)
# Found 2066 valid paired samples.
# Example pair: (PosixPath('/content/train_data/s2_image/train_s2_image_0.tif'), PosixPath('/content/train_data/mask/train_mask_0.tif'))

# %%
# Quick sanity check: visualize one random pair out of the first 31 available
# Run this cell a few times to check that you have different files and that the mask looks about right
pair_num = np.random.randint(0,30)
s2_path, mask_path = pairs[pair_num]

with rasterio.open(s2_path) as src:
    s2_img = src.read([3,2,1])  # RGB bands for Sentinel-2 (B4, B3, B2)
    s2_img = np.transpose(s2_img, (1,2,0))
    s2_img = (s2_img - s2_img.min()) / (s2_img.max() - s2_img.min())

with rasterio.open(mask_path) as src:
    mask = src.read(1)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(s2_img)
plt.title("Sentinel-2 RGB Patch")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(mask, cmap="gray")
plt.title("Mask")
plt.axis("off")
plt.show()

# %% [markdown]
# Next up we are going to prepare our training data into numpy arrays that are then able to be passed into TensorFlow. However, if we try to hold all 2000+ patches in RAM whilst we do, the Colab instance will crash. If on your own laptop, it will also die unless you have spent a lot more money than I have on mine. Furthermore, even if we had a HPC level of RAM available it is a good idea to do things in a 'memory safe' manner that means we can scale our training with more samples if we so deisred it.
#
# The safe pattern is therefore to:
# 1. Load a batch of patches.
# 2. Normalize/resize them.
# 3. Save them to disk (e.g. as .npy, .npz, or TFRecords/HDF5).
# 4. Free memory and move on.
# 5. Then later, when training, you stream batches directly from disk.
#
# Here’s a disk-based pipeline with batching using numpy.savez_compressed (safe + easy to reload):

# %%
def resize_or_pad(arr, target_h, target_w):
    h, w = arr.shape[:2]
    c = arr.shape[2] if arr.ndim == 3 else 1

    arr = cv2.resize(
        arr,
        (target_w, target_h),
        interpolation=cv2.INTER_NEAREST if c == 1 else cv2.INTER_LINEAR)

    if arr.ndim == 2:
        arr = arr[..., np.newaxis]
    return arr


# Set storage folder
OUTPUT_DIR = "patch_store"
os.makedirs(OUTPUT_DIR, exist_ok=True)

TARGET_HEIGHT, TARGET_WIDTH = 256, 256 # Tune based on memory available
BATCH_SIZE = 100  # Tune based on memory available


X_batch, Y_batch = [], []
batch_idx = 0

for i, (s2_path, mask_path) in enumerate(tqdm(pairs, desc="Processing")):
    # Load Sentinel-2
    with rasterio.open(s2_path) as src:
        img = src.read().astype(np.float32)  # (bands, H, W)
        img = np.transpose(img, (1, 2, 0))  # (H, W, bands)

    # Load mask
    with rasterio.open(mask_path) as src:
        mask = src.read(1).astype(np.uint8)

    # Resize/pad
    img = resize_or_pad(img, TARGET_HEIGHT, TARGET_WIDTH)
    mask = resize_or_pad(mask, TARGET_HEIGHT, TARGET_WIDTH)

    # Normalize
    img = img / 10000.0

    # Add to batch
    X_batch.append(img)
    Y_batch.append(mask)

    # Save batch to disk when full
    if len(X_batch) >= BATCH_SIZE:
        X_batch = np.stack(X_batch)
        Y_batch = np.stack(Y_batch)

        np.savez_compressed(
            os.path.join(OUTPUT_DIR, f"batch_{batch_idx:04d}.npz"),
            X=X_batch, Y=Y_batch
        )

        # Reset
        batch_idx += 1
        X_batch, Y_batch = [], []

# Save any leftovers
if len(X_batch) > 0:
    X_batch = np.stack(X_batch)
    Y_batch = np.stack(Y_batch)
    np.savez_compressed(
        os.path.join(OUTPUT_DIR, f"batch_{batch_idx:04d}.npz"),
        X=X_batch, Y=Y_batch
    )

# By the way it is the 'tqdm' element that is providing the nifty progress bar. I always like to include it when waiting for things so that I know it is actually running.

# This block might take five to ten minutes to run as we are doing this in a linear manner (rather than parallell processing).
# An optimised version of thise code is to pass each batch to a seperate CPU thread/core.
# Out:
# Processing: 100%|██████████| 2066/2066 [07:18<00:00,  4.71it/s]

# %% [markdown]
# 5-10 minutes later... (mine took 8 minutes and 32 seconds), we can now move on. Because we are now not storing our training data in our RAM like we did in the lecture exercise, we have to load it in as we want it.

# %% [markdown]
# First up, set a bunch of parameters that we can modify in order to save our RAM load. In short, the lower these values the less RAM you will use but the worse the results:

# %%
# Paramaters for RAM saving
TARGET_HEIGHT, TARGET_WIDTH = 128, 128  # smaller patch -> saves RAM & compute
BANDS = 3  # RGB only -> reduces memory
BATCH_SIZE = 4  # small batch -> reduces RAM usage
MAX_TRAIN_FILES = 5  # only use subset for lab demonstration
MAX_VAL_FILES = 2

# %% [markdown]
# **Q1**: We have used three bands here. What is the total numnber of bands we could make available to the CNN if we so chose?

# %%
with rasterio.open(pairs[0][0]) as src:
    print('Number of bands:', src.count)
    print('Data type:', src.dtypes)
    print('Size:', src.height, 'x', src.width)
# Out:
# Number of bands: 12
# Data type: ('float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64', 'float64')
# Size: 24 x 23

# %% [markdown]
# Next we find our patch files:

# %%
# Locate the batched .npz files
all_files = sorted(glob.glob("patch_store/*.npz"))
np.random.shuffle(all_files)

train_files = all_files[:MAX_TRAIN_FILES]
val_files   = all_files[-MAX_VAL_FILES:]

# %% [markdown]
# **Q2**: What is the total number of patches in our training data and the total number in our validation set? (With the parameters set as I have done in the notebook).
#
# Tip: you can either programmatically count what is in train_files/val_files, or you can calculate it from the parameters that have been set across the cells above this one.

# %%
print('Total number of npz files:', len(all_files))
print('train_files:', [Path(f).name for f in train_files])
print('val_files:', [Path(f).name for f in val_files])

def count_patches(files):
    return sum(np.load(f)["X"].shape[0] for f in files)

print('Total number of training patches:', count_patches(train_files))
print('Verify total number of patches:', count_patches(val_files))
# Out:
# Total number of npz files: 21
# train_files: ['batch_0000.npz', 'batch_0013.npz', 'batch_0008.npz', 'batch_0001.npz', 'batch_0015.npz']
# val_files: ['batch_0014.npz', 'batch_0019.npz']
# Total number of training patches: 500
# Verify total number of patches: 200

# %% [markdown]
# We then we need to change our masks to a binary label. If we were doing segmenation we would keep it as a mask, but in this case we are just trying to find patches that contain solar pannels rather than the specific solar pannel outline.

# %%
# Mask to binary label
def mask_to_label(mask_batch):
    """1 if any solar pixel in mask, else 0"""
    labels = (np.sum(mask_batch, axis=(1,2,3)) > 0).astype(np.float32)
    return labels

# %% [markdown]
# Now we need a tool to load our data in from the batched files:

# %%
# Data loader
def npz_loader_cls(path):
    """Load one .npz batch, downsample patches, convert to RGB, convert mask to label"""
    data = np.load(path.numpy().decode("utf-8"))
    X = data["X"]
    Y_mask = data["Y"]

    # RAM saving: pick first 3 bands only
    X = X[..., :BANDS]

    # RAM saving: downsample patches
    from skimage.transform import resize
    X_resized = np.zeros((X.shape[0], TARGET_HEIGHT, TARGET_WIDTH, BANDS), dtype=np.float32)
    for i in range(X.shape[0]):
        X_resized[i] = resize(X[i], (TARGET_HEIGHT, TARGET_WIDTH, BANDS), anti_aliasing=True)

    X = X_resized

    Y = mask_to_label(Y_mask)
    return X, Y

# %% [markdown]
# We can now define our training and validation datasets, which will only be actually populated with data as required, rather than loading it all into memory at once.

# %%
# TensorFlow dataset pipeline
def tf_wrapper(path):
    X, Y = tf.py_function(npz_loader_cls, [path], [tf.float32, tf.float32])
    X.set_shape([None, TARGET_HEIGHT, TARGET_WIDTH, BANDS])
    Y.set_shape([None])
    # Flatten file-batch into individual samples
    return tf.data.Dataset.from_tensor_slices((X, Y))

def make_cls_dataset(file_list, batch_size=BATCH_SIZE, shuffle=True, repeat=True):
    files = tf.data.Dataset.from_tensor_slices(file_list)
    if shuffle:
        files = files.shuffle(len(file_list))

    # RAM saving: stream samples via interleave
    ds = files.interleave(
        lambda f: tf_wrapper(f),
        cycle_length=4,
        num_parallel_calls=tf.data.AUTOTUNE)

    if shuffle:
        ds = ds.shuffle(2048)

    ds = ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    if repeat:
        ds = ds.repeat()

    return ds

train_ds = make_cls_dataset(train_files, batch_size=BATCH_SIZE, shuffle=True)
val_ds   = make_cls_dataset(val_files, batch_size=BATCH_SIZE, shuffle=False, repeat=False)

# %% [markdown]
# **Q3**: Are we shuffling the training dataset? Are we shuffling the validation dataset?

# %% [markdown]
# Finally, we need to specify our model settings. We are just using a simple CNN here, the same sort as we used the lecture exercise. But, this time it has signficantly more layers and therefore parameters (but far less than you might use for your project). It may take a few minutes to set up:

# %%
# We are determining the input shape from one batch first
for X_sample, _ in train_ds.take(1):
    input_shape = X_sample.shape[1:]  # (H, W, bands)
    break

# Define a simple CNN
inputs = layers.Input(shape=input_shape)
x = layers.Conv2D(16, 3, activation='relu', padding='same')(inputs)
x = layers.MaxPooling2D((2,2))(x)
x = layers.Conv2D(32, 3, activation='relu', padding='same')(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(32, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model = models.Model(inputs, outputs)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 32)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,177 (24.13 KB)
#  Trainable params: 6,177 (24.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Q4**: Which type of activation funding is our final layer using and why are we using this function as our final layer?

# %% [markdown]
# With the model ready to train, we have one more preperation step to make. We need to count the total samples available in this particular run. This is because you can change the number of samples via the RAM paramaters earlier, and therefore we should assume in this code a static number of samples will always be available when setting our number of steps per epoch.

# %%
# Count the total samples
def count_samples(files):
    total = 0
    for f in files:
        total += np.load(f)["X"].shape[0]
    return total

n_train = count_samples(train_files)
n_val   = count_samples(val_files)

steps_per_epoch = max(1, n_train // BATCH_SIZE)
validation_steps = max(1, n_val // BATCH_SIZE)

# %% [markdown]
# Finally, we train the model! It should take 5-10 minutes to run on a free-user Colab notebook.

# %%
# This 'callbacks' set of instructions is a handy way to avoid wasting time
callbacks = [
    EarlyStopping(
        monitor="val_loss",          # Watch the validation loss
        patience=3,                  # If it doesn't improve for 3 epochs, stop training
        restore_best_weights=True    # Roll back to the best-performing weights
    )]

# Run the model
history = model.fit(
    train_ds,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_ds,
    validation_steps=validation_steps,
    epochs=5,  # small number for lab demonstration
    callbacks=callbacks)
# Out:
# Epoch 1/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 38s 150ms/step - accuracy: 0.9180 - loss: 0.3532 - val_accuracy: 0.9150 - val_loss: 0.2981
# Epoch 2/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 29s 148ms/step - accuracy: 0.9340 - loss: 0.2595 - val_accuracy: 0.9150 - val_loss: 0.2994
# Epoch 3/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 29s 150ms/step - accuracy: 0.9340 - loss: 0.2590 - val_accuracy: 0.9150 - val_loss: 0.2983
# Epoch 4/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 29s 150ms/step - accuracy: 0.9340 - loss: 0.2566 - val_accuracy: 0.9150 - val_loss: 0.3077

# %% [markdown]
# Visualizie the predictions:

# %%
# Plot the training curves
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label="train")
plt.plot(history.history['val_loss'], label="val")
plt.title("Loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label="train")
plt.plot(history.history['val_accuracy'], label="val")
plt.title("Accuracy")
plt.legend()
plt.show()

# %%
def show_patch_predictions_grid(dataset, model, n_rows=2, n_cols=5):
    """
    Display predictions in a grid: n_rows x n_cols
    Includes histogram stretch for better visualization of RGB patches.
    """
    def stretch(img):
        """Contrast stretch to 0–1 for display."""
        img = img.astype(np.float32)
        p2, p98 = np.percentile(img, (2, 98))
        img = np.clip((img - p2) / (p98 - p2 + 1e-6), 0, 1)
        return img

    for X, Y_true in dataset.take(1):
        # live classification of the patch using the trained model
        Y_pred = model.predict(X, verbose=0)
        n_total = min(n_rows * n_cols, X.shape[0])

        fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols*3, n_rows*3))
        axes = axes.flatten()

        for i in range(n_total):
            rgb = X[i, :, :, :3].numpy()
            rgb = stretch(rgb)  # apply histogram stretch
            axes[i].imshow(rgb)
            axes[i].set_title(f"T:{int(Y_true[i].numpy())}\nP:{Y_pred[i,0]:.2f}")
            axes[i].axis("off")

        # hide any unused axes
        for i in range(n_total, len(axes)):
            axes[i].axis("off")

        plt.tight_layout()
        plt.show()

# Example
show_patch_predictions_grid(val_ds, model, n_rows=1, n_cols=5)

# %% [markdown]
# Remembering that this is a effectively still a toy CNN with tiny data, we can see that we have built a model that gives us a probability of the patches containing a solar pannel. We know that for all of the patchs used in this training, the answer is true...

# %% [markdown]
# **Q5**: Is this a robust and reliable model for the detection of solar panels in a new Sentinel 2 image that has never been seen by the model before? Explain your answer with reference to the design of the training data, the settings of the CNN and the performance statistics seen.

# %%
d = np.load(train_files[0])
labels = mask_to_label(d["Y"])
print('Label value distribution:', np.unique(labels, return_counts=True))
print('Positive sample ratio:', labels.mean())
# Out:
# Label value distribution: (array([0., 1.], dtype=float32), array([ 7, 93]))
# Positive sample ratio: 0.93

# %% [markdown]
# **Q6**: Exercise: using the materials taught in Lab 3 and given your answer to Q5, re-design your training data so that it is a robust training set for the detection of solar panels in S2 data. Your answer needs to include:
# *   A paragraph that explains what you have added to the train_data and any other steps taken in order to enhance the robustness of the training.
# *   A figure that demonstrates your newly added patches vs. the existing patches (remember that it needs to be publication quality).
#
# You do not need to create a 100% solution here. I am looking for you to demonstrate an understanding of the critical design flaw in this training set (particularly for a patch based, as opposed to segmentation, approach), and to show critical thinking in how you might fix it. This may include re-sampling the existing training data, including new training data, or changing the bands being used (or all of the above).

# %%
d = np.load(train_files[0])
print('X shape:', d["X"].shape, '  Y shape:', d["Y"].shape)
print('Panel pixel ratio:', (d["Y"] > 0).mean())

import rasterio
with rasterio.open(pairs[0][0]) as src:
    print('Band description:', src.descriptions)
# Out:
# X shape: (100, 256, 256, 12)   Y shape: (100, 256, 256, 1)
# Panel pixel ratio: 0.09795379638671875
# Band description: (None, None, None, None, None, None, None, None, None, None, None, None)
# /usr/local/lib/python3.13/dist-packages/rasterio/__init__.py:367: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, thread_safe=thread_safe, **kwargs)

# %%
d = np.load(train_files[0])
X = d["X"]
print('Mean values ​​for each band:')
for i in range(12):
    print(f'  band {i}: {X[..., i].mean():.4f}')
# Out:
# Mean values ​​for each band:
#   band 0: 0.0577
#   band 1: 0.0648
#   band 2: 0.0829
#   band 3: 0.0851
#   band 4: 0.1199
#   band 5: 0.1875
#   band 6: 0.2113
#   band 7: 0.2283
#   band 8: 0.2315
#   band 9: 0.2336
#   band 10: 0.2083
#   band 11: 0.1404

# %%
# Q6.1 Extract negative samples from existing patches
import numpy as np, os, glob
from pathlib import Path

CROP = 96
N_TRY = 30
RNG = np.random.default_rng(SEED)

def crop_samples_from_batch(X, Y, crop=CROP, n_try=N_TRY):
    pos, neg = [], []
    H, W = Y.shape[1], Y.shape[2]
    for i in range(X.shape[0]):
        got_neg = False
        for _ in range(n_try):
            r = RNG.integers(0, H - crop)
            c = RNG.integers(0, W - crop)
            sub_mask = Y[i, r:r+crop, c:c+crop, 0]
            sub_img  = X[i, r:r+crop, c:c+crop, :]
            if sub_mask.sum() == 0 and not got_neg:
                neg.append(sub_img); got_neg = True
            elif sub_mask.sum() > 0 and len(pos) < len(neg) + 2:
                pos.append(sub_img)
        # Ensure that each original patch contributes at least one positive sample.
        if Y[i].sum() > 0:
            # Find a sub-block that actually contains a panel.
            for _ in range(n_try):
                r = RNG.integers(0, H - crop)
                c = RNG.integers(0, W - crop)
                if Y[i, r:r+crop, c:c+crop, 0].sum() > 0:
                    pos.append(X[i, r:r+crop, c:c+crop, :]); break
    return pos, neg


# Do this for all npz files.
all_pos, all_neg = [], []
for f in sorted(glob.glob("patch_store/*.npz")):
    d = np.load(f)
    p, n = crop_samples_from_batch(d["X"], d["Y"])
    all_pos.extend(p); all_neg.extend(n)

all_pos = np.array(all_pos, dtype=np.float32)
all_neg = np.array(all_neg, dtype=np.float32)
print(f'Cut out positive samples {len(all_pos)} ，negative samples {len(all_neg)} ')
# Out:
# Cut out positive samples 1983 ，negative samples 1681

# %%
# Q6.2 Select bands, balance categories, and save as a new training set.
# Band Index
BAND_IDX = [0, 1, 2, 6, 10, 11]     # B2, B3, B4, B8(NIR), B11, B12(SWIR)

all_pos = all_pos[..., BAND_IDX]
all_neg = all_neg[..., BAND_IDX]

# Category balance
n_bal = min(len(all_pos), len(all_neg))
idx_p = RNG.choice(len(all_pos), n_bal, replace=False)
idx_n = RNG.choice(len(all_neg), n_bal, replace=False)

X_bal = np.concatenate([all_pos[idx_p], all_neg[idx_n]])
Y_bal = np.concatenate([np.ones(n_bal, np.float32), np.zeros(n_bal, np.float32)])

# After shuffling, divide the data into 70/30 categories to ensure
# that the proportions of each category are consistent on both sides.
order = RNG.permutation(len(X_bal))
X_bal, Y_bal = X_bal[order], Y_bal[order]
split = int(0.7 * len(X_bal))

BAL_DIR = "patch_store_balanced"
os.makedirs(BAL_DIR, exist_ok=True)
np.savez_compressed(f"{BAL_DIR}/train.npz", X=X_bal[:split], Y=Y_bal[:split])
np.savez_compressed(f"{BAL_DIR}/val.npz",   X=X_bal[split:], Y=Y_bal[split:])

print(f'Balanced total sample {len(X_bal)}，positive sample ratio {Y_bal.mean():.2f}')
print(f'train {split} ，validation {len(X_bal)-split} ')
print(f'proportion of positive samples in the training set {Y_bal[:split].mean():.2f}，Validation set {Y_bal[split:].mean():.2f}')
# Out:
# Balanced total sample 3362，positive sample ratio 0.50
# train 2353 ，validation 1009
# proportion of positive samples in the training set 0.50，Validation set 0.50

# %%
# Q6.3 Output image
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def to_rgb(img):
    rgb = img[..., [2, 1, 0]]              # B2,B3,B4 → B4,B3,B2
    return np.clip(rgb / 0.30, 0, 1) ** (1/1.4)   # Fixed upper limit + gamma brightening

N = 6
idx_p = RNG.choice(len(all_pos), N, replace=False)
idx_n = RNG.choice(len(all_neg), N, replace=False)

fig, axes = plt.subplots(2, N, figsize=(2.3*N, 5.8))
for j in range(N):
    axes[0, j].imshow(to_rgb(all_pos[idx_p[j]]))
    axes[0, j].set_title('label = 1', fontsize=9); axes[0, j].axis('off')
    axes[1, j].imshow(to_rgb(all_neg[idx_n[j]]))
    axes[1, j].set_title('label = 0', fontsize=9); axes[1, j].axis('off')

fig.text(0.055, 0.72, 'Existing patches\nsolar panel present',
         ha='center', va='center', fontsize=10, rotation=90)
fig.text(0.055, 0.27, 'Added crops\nno solar panel',
         ha='center', va='center', fontsize=10, rotation=90)

plt.tight_layout(rect=[0.085, 0, 1, 1])
plt.savefig('Q6_training_patches.png', dpi=300, bbox_inches='tight')
plt.show()
from google.colab import files
files.download('Q6_training_patches.png')

# %% [markdown]
# **Q7**: Exercise: re-run the model with your new training data (remembering that I am not looking for a total solution), and further adjusted hyperparameters/RAM options. Write two paragraphs that:
# 1. Sets out **all the changes** you have made and the reasoning for them.
# 2. Asses the training and model results in terms of performance statistics, commenting on how/if your training data changes have made an impact.
#
# You may include figures to support your analysis if you wish, remembering to present them to publication standard if you do so.

# %%
# Q7.1 Build a new tf.data pipeline using the balanced data.
BANDS_NEW = 6          # B2,B3,B4,B8,B11,B12
IMG_SIZE  = 96         # Consistent with the cutting size,
BATCH_NEW = 16

tr = np.load("patch_store_balanced/train.npz")
va = np.load("patch_store_balanced/val.npz")
X_tr, Y_tr = tr["X"], tr["Y"]
X_va, Y_va = va["X"], va["Y"]
print('train', X_tr.shape, ' val', X_va.shape)

train_ds2 = (tf.data.Dataset.from_tensor_slices((X_tr, Y_tr))
             .shuffle(2048, seed=SEED).batch(BATCH_NEW).prefetch(tf.data.AUTOTUNE))
val_ds2   = (tf.data.Dataset.from_tensor_slices((X_va, Y_va))
             .batch(BATCH_NEW).prefetch(tf.data.AUTOTUNE))
# Out:
# train (2353, 96, 96, 6)  val (1009, 96, 96, 6)

# %%
# Q7.2 Model
data_aug = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.25),
], name="augment")

inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, BANDS_NEW))
x = data_aug(inputs)
x = layers.Conv2D(16, 3, activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2,2))(x)
x = layers.Conv2D(32, 3, activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2,2))(x)
x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(32, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model2 = models.Model(inputs, outputs)
model2.compile(optimizer='adam', loss='binary_crossentropy',
               metrics=['accuracy',
                        tf.keras.metrics.Precision(name='precision'),
                        tf.keras.metrics.Recall(name='recall'),
                        tf.keras.metrics.AUC(name='auc')])
model2.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 6)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ augment (Sequential)            │ (None, 96, 96, 6)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 96, 96, 16)     │           880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 48, 48, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 48, 48, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,129 (102.07 KB)
#  Trainable params: 26,129 (102.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Q7.3 Training
callbacks2 = [EarlyStopping(monitor="val_loss", patience=5,
                            restore_best_weights=True)]
history2 = model2.fit(train_ds2, validation_data=val_ds2,
                      epochs=30, callbacks=callbacks2)
# Out:
# Epoch 1/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 37s 208ms/step - accuracy: 0.5325 - auc: 0.5541 - loss: 0.6877 - precision: 0.5303 - recall: 0.5384 - val_accuracy: 0.5837 - val_auc: 0.6821 - val_loss: 0.6675 - val_precision: 0.6862 - val_recall: 0.3222
# Epoch 2/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 30s 204ms/step - accuracy: 0.5971 - auc: 0.6334 - loss: 0.6659 - precision: 0.6033 - recall: 0.5580 - val_accuracy: 0.6591 - val_auc: 0.7345 - val_loss: 0.6289 - val_precision: 0.6503 - val_recall: 0.7014
# Epoch 3/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 30s 202ms/step - accuracy: 0.6405 - auc: 0.6898 - loss: 0.6308 - precision: 0.6701 - recall: 0.5478 - val_accuracy: 0.7047 - val_auc: 0.7792 - val_loss: 0.5759 - val_precision: 0.7989 - val_recall: 0.5540
# Epoch 4/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 44s 222ms/step - accuracy: 0.6910 - auc: 0.7372 - loss: 0.5884 - precision: 0.7526 - recall: 0.5657 - val_accuracy: 0.6640 - val_auc: 0.7818 - val_loss: 0.5999 - val_precision: 0.9048 - val_recall: 0.3733
# Epoch 5/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 30s 202ms/step - accuracy: 0.7051 - auc: 0.7436 - loss: 0.5793 - precision: 0.7710 - recall: 0.5802 - val_accuracy: 0.7592 - val_auc: 0.8204 - val_loss: 0.5386 - val_precision: 0.8342 - val_recall: 0.6523
# Epoch 6/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.7242 - auc: 0.7736 - loss: 0.5556 - precision: 0.7839 - recall: 0.6160 - val_accuracy: 0.7126 - val_auc: 0.8158 - val_loss: 0.5627 - val_precision: 0.8897 - val_recall: 0.4912
# Epoch 7/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 42s 209ms/step - accuracy: 0.7323 - auc: 0.7797 - loss: 0.5518 - precision: 0.7914 - recall: 0.6280 - val_accuracy: 0.7621 - val_auc: 0.8357 - val_loss: 0.5287 - val_precision: 0.7930 - val_recall: 0.7151
# Epoch 8/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 30s 204ms/step - accuracy: 0.7331 - auc: 0.7922 - loss: 0.5389 - precision: 0.7894 - recall: 0.6331 - val_accuracy: 0.7681 - val_auc: 0.8385 - val_loss: 0.5268 - val_precision: 0.7723 - val_recall: 0.7662
# Epoch 9/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 41s 202ms/step - accuracy: 0.7501 - auc: 0.8107 - loss: 0.5216 - precision: 0.7868 - recall: 0.6834 - val_accuracy: 0.7631 - val_auc: 0.8455 - val_loss: 0.5170 - val_precision: 0.7616 - val_recall: 0.7721
# Epoch 10/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 31s 208ms/step - accuracy: 0.7459 - auc: 0.8042 - loss: 0.5265 - precision: 0.7864 - recall: 0.6724 - val_accuracy: 0.7681 - val_auc: 0.8430 - val_loss: 0.5104 - val_precision: 0.8282 - val_recall: 0.6817
# Epoch 11/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 31s 208ms/step - accuracy: 0.7505 - auc: 0.8085 - loss: 0.5167 - precision: 0.7741 - recall: 0.7048 - val_accuracy: 0.7820 - val_auc: 0.8447 - val_loss: 0.5023 - val_precision: 0.8204 - val_recall: 0.7269
# Epoch 12/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 31s 207ms/step - accuracy: 0.7505 - auc: 0.8024 - loss: 0.5272 - precision: 0.7958 - recall: 0.6715 - val_accuracy: 0.7651 - val_auc: 0.8311 - val_loss: 0.5262 - val_precision: 0.8716 - val_recall: 0.6267
# Epoch 13/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 32s 214ms/step - accuracy: 0.7535 - auc: 0.8163 - loss: 0.5154 - precision: 0.7782 - recall: 0.7065 - val_accuracy: 0.7651 - val_auc: 0.8373 - val_loss: 0.5222 - val_precision: 0.8757 - val_recall: 0.6228
# Epoch 14/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 31s 212ms/step - accuracy: 0.7391 - auc: 0.7894 - loss: 0.5409 - precision: 0.7672 - recall: 0.6834 - val_accuracy: 0.7671 - val_auc: 0.8357 - val_loss: 0.5215 - val_precision: 0.8683 - val_recall: 0.6346
# Epoch 15/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 41s 209ms/step - accuracy: 0.7527 - auc: 0.8094 - loss: 0.5159 - precision: 0.7892 - recall: 0.6869 - val_accuracy: 0.7701 - val_auc: 0.8404 - val_loss: 0.5089 - val_precision: 0.8403 - val_recall: 0.6719
# Epoch 16/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 31s 207ms/step - accuracy: 0.7573 - auc: 0.8258 - loss: 0.5050 - precision: 0.7666 - recall: 0.7372 - val_accuracy: 0.7750 - val_auc: 0.8447 - val_loss: 0.5018 - val_precision: 0.8634 - val_recall: 0.6582
# Epoch 17/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 30s 206ms/step - accuracy: 0.7518 - auc: 0.8108 - loss: 0.5191 - precision: 0.7697 - recall: 0.7159 - val_accuracy: 0.7790 - val_auc: 0.8514 - val_loss: 0.4960 - val_precision: 0.7918 - val_recall: 0.7623
# Epoch 18/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 33s 223ms/step - accuracy: 0.7531 - auc: 0.8161 - loss: 0.5121 - precision: 0.7689 - recall: 0.7210 - val_accuracy: 0.7592 - val_auc: 0.8555 - val_loss: 0.5306 - val_precision: 0.7224 - val_recall: 0.8487
# Epoch 19/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 31s 207ms/step - accuracy: 0.7667 - auc: 0.8255 - loss: 0.5028 - precision: 0.7845 - recall: 0.7329 - val_accuracy: 0.7750 - val_auc: 0.8495 - val_loss: 0.4964 - val_precision: 0.8205 - val_recall: 0.7092
# Epoch 20/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 41s 205ms/step - accuracy: 0.7544 - auc: 0.8099 - loss: 0.5120 - precision: 0.7786 - recall: 0.7082 - val_accuracy: 0.7661 - val_auc: 0.8394 - val_loss: 0.5200 - val_precision: 0.8740 - val_recall: 0.6267
# Epoch 21/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 32s 216ms/step - accuracy: 0.7582 - auc: 0.8122 - loss: 0.5118 - precision: 0.7936 - recall: 0.6954 - val_accuracy: 0.7740 - val_auc: 0.8515 - val_loss: 0.5033 - val_precision: 0.7827 - val_recall: 0.7642
# Epoch 22/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 43s 228ms/step - accuracy: 0.7531 - auc: 0.8228 - loss: 0.5051 - precision: 0.7718 - recall: 0.7159 - val_accuracy: 0.7849 - val_auc: 0.8550 - val_loss: 0.4935 - val_precision: 0.8133 - val_recall: 0.7446
# Epoch 23/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - accuracy: 0.7641 - auc: 0.8317 - loss: 0.4988 - precision: 0.7709 - recall: 0.7491 - val_accuracy: 0.7740 - val_auc: 0.8490 - val_loss: 0.5017 - val_precision: 0.8612 - val_recall: 0.6582
# Epoch 24/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 41s 208ms/step - accuracy: 0.7573 - auc: 0.8285 - loss: 0.5008 - precision: 0.7602 - recall: 0.7491 - val_accuracy: 0.7909 - val_auc: 0.8530 - val_loss: 0.4871 - val_precision: 0.8417 - val_recall: 0.7210
# Epoch 25/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 31s 213ms/step - accuracy: 0.7629 - auc: 0.8159 - loss: 0.5054 - precision: 0.7896 - recall: 0.7142 - val_accuracy: 0.7849 - val_auc: 0.8555 - val_loss: 0.4830 - val_precision: 0.8080 - val_recall: 0.7525
# Epoch 26/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 31s 207ms/step - accuracy: 0.7688 - auc: 0.8297 - loss: 0.4980 - precision: 0.7886 - recall: 0.7321 - val_accuracy: 0.7879 - val_auc: 0.8572 - val_loss: 0.4808 - val_precision: 0.8092 - val_recall: 0.7583
# Epoch 27/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 30s 206ms/step - accuracy: 0.7616 - auc: 0.8369 - loss: 0.4935 - precision: 0.7574 - recall: 0.7671 - val_accuracy: 0.7730 - val_auc: 0.8631 - val_loss: 0.4831 - val_precision: 0.7527 - val_recall: 0.8193
# Epoch 28/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 31s 207ms/step - accuracy: 0.7692 - auc: 0.8332 - loss: 0.4981 - precision: 0.7791 - recall: 0.7491 - val_accuracy: 0.7839 - val_auc: 0.8562 - val_loss: 0.4820 - val_precision: 0.7916 - val_recall: 0.7760
# Epoch 29/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 30s 203ms/step - accuracy: 0.7633 - auc: 0.8304 - loss: 0.4990 - precision: 0.7743 - recall: 0.7406 - val_accuracy: 0.7800 - val_auc: 0.8528 - val_loss: 0.4925 - val_precision: 0.8254 - val_recall: 0.7151
# Epoch 30/30
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 30s 203ms/step - accuracy: 0.7684 - auc: 0.8339 - loss: 0.4945 - precision: 0.7792 - recall: 0.7466 - val_accuracy: 0.7810 - val_auc: 0.8515 - val_loss: 0.4992 - val_precision: 0.8600 - val_recall: 0.6758

# %%
# Q7.4 Assessment
from sklearn.metrics import confusion_matrix, classification_report

Y_prob = model2.predict(val_ds2, verbose=0).ravel()
Y_pred = (Y_prob > 0.5).astype(int)

print(classification_report(Y_va.astype(int), Y_pred,
                            target_names=['no panel', 'panel'], digits=3))
cm = confusion_matrix(Y_va.astype(int), Y_pred)
print('Confusion matrix:\n', cm)

# Comparison: Baseline of the original model (always predicts 1)
print(f'\nbaseline (all judged as 1) Accuracy:{Y_va.mean():.3f}')
# Out:
#               precision    recall  f1-score   support
#
#     no panel      0.769     0.818     0.793       500
#        panel      0.809     0.758     0.783       509
#
#     accuracy                          0.788      1009
#    macro avg      0.789     0.788     0.788      1009
# weighted avg      0.789     0.788     0.788      1009
#
# Confusion matrix:
#  [[409  91]
#  [123 386]]
#
# baseline (all judged as 1) Accuracy:0.504

# %%
# Q7.5 Output image
fig, axes = plt.subplots(1, 3, figsize=(15, 4.2))

best = int(np.argmin(history2.history['val_loss']))
axes[0].axvline(best, ls=':', c='grey', lw=1)
axes[0].annotate(f'best epoch {best}', xy=(best, min(history2.history['val_loss'])),
                 xytext=(best+1.5, min(history2.history['val_loss'])+0.02),
                 fontsize=8, color='grey')
axes[0].plot(history2.history['loss'], label='train')
axes[0].plot(history2.history['val_loss'], label='validation')
axes[0].set_xlabel('Epoch'); axes[0].set_ylabel('Binary cross-entropy')
axes[0].set_title('(a) Loss'); axes[0].legend()

axes[1].plot(history2.history['accuracy'], label='train')
axes[1].plot(history2.history['val_accuracy'], label='validation')
axes[1].set_ylim(0.45, 0.82)
axes[1].axhline(0.5, ls='--', c='grey', lw=1, label='majority-class baseline')
axes[1].set_xlabel('Epoch'); axes[1].set_ylabel('Accuracy')
axes[1].set_title('(b) Accuracy'); axes[1].legend()

im = axes[2].imshow(cm, cmap='Blues')
for (i, j), v in np.ndenumerate(cm):
    axes[2].text(j, i, str(v), ha='center', va='center',
                 color='white' if v > cm.max()/2 else 'black', fontsize=12)
axes[2].set_xticks([0,1]); axes[2].set_xticklabels(['no panel', 'panel'])
axes[2].set_yticks([0,1]); axes[2].set_yticklabels(['no panel', 'panel'])
axes[2].set_xlabel('Predicted'); axes[2].set_ylabel('True')
axes[2].set_title('(c) Confusion matrix, validation set')

plt.tight_layout()
plt.savefig('Q7_results.png', dpi=300, bbox_inches='tight')
plt.show()
files.download('Q7_results.png')
